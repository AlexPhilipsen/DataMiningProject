# %% [markdown]
# # Data Mining Project
# ## By Bobby Vu and Alex Philipsen

# %% [markdown]
# ### Getting Data from logs.tf

# %%
# Format for API: http://logs.tf/api/v1/log/<log_id>

# This is an example of how querying the API works
# as well as what the data will look like

import requests
import json

# This gets the log from just one game
response = requests.get("http://logs.tf/api/v1/log/3736855")

if(response.status_code == 200):
    data = response.json()
    print(json.dumps(data, indent=4))
# Out:
# {
#     "version": 3,
#     "teams": {
#         "Red": {
#             "score": 3,
#             "kills": 115,
#             "deaths": 0,
#             "dmg": 44581,
#             "charges": 9,
#             "drops": 1,
#             "firstcaps": 3,
#             "caps": 20
#         },
#         "Blue": {
#             "score": 3,
#             "kills": 114,
#             "deaths": 0,
#             "dmg": 42339,
#             "charges": 13,
#             "drops": 0,
#             "firstcaps": 4,
#             "caps": 21
#         }
#     },
#     "length": 1738,
#     "players": {
#         "[U:1:180084244]": {
#             "team": "Red",
#             "class_stats": [
#                 {
#                     "type": "soldier",
#                     "kills": 17,
#                     "assists": 2,
#                     "deaths": 22,
#                     "dmg": 7175,
#                     "weapon": {
#                         "rocketlauncher_directhit": {
#                             "kills": 5,
#                             "dmg": 2277,
#                             "avg_dmg": 81.32142857142857,
#                             "shots": 88,
#                             "hits": 27
#                         },
#                         "tf_projectile_rocket": {
#                             "kills": 10,
#                             "dmg": 4798,
#                             "avg_dmg": 57.80722891566265,
#                             "shots": 190,
#                             "hits": 76
#                         },
#                         "panic_attack": {
#                             "kills": 1,
#                             "dmg": 100,
#                             "avg_dmg": 20,
#                             "shots": 6,
#                             "hits": 4
#                         },
#                         "world": {
#                             "kills": 1,
#                             "dmg": 0,
#                             "avg_dmg": 0,
#                             "shots": 0,
#                             "hits": 0
#                         }
#                     },
#                     "total_time": 1591
#                 },
#                 {
#                     "type": "heavyweapons",
#                     "kills": 0,
#                     "assists": 1,
#                     "deaths": 1,
#                     "dmg": 179,
#                     "weapon": {
#                         "iron_curtain": {
#                             "kills": 0,
#                             "dmg": 179,
#                             "avg_dmg": 5.59375,
#                             "shots": 0,
#                             "hits": 0
#                         }
#                     },
#                     "total_time": 114
#                 },
#                 {
#                     "type": "sniper",
#                     "kills": 1,
#                     "assists": 0,
#                     "deaths": 1,
#                     "dmg": 306,
#                     "weapon": {
#                         "awper_hand": {
#                             "kills": 1,
#                             "dmg": 306,
#                             "avg_dmg": 306,
#                             "shots": 3,
#                             "hits": 1
#                         },
#                         "smg": {
#                             "kills": 0,
#                             "dmg": 0,
#                             "avg_dmg": 0,
#                             "shots": 3,
#                             "hits": 0
#                         }
#                     },
#                     "total_time": 33
#                 }
#             ],
#             "kills": 18,
#             "deaths": 24,
#             "assists": 3,
#             "suicides": 0,
#             "kapd": "0.9",
#             "kpd": "0.8",
#             "dmg": 7660,
#             "dmg_real": 980,
#             "dt": 7444,
#             "dt_real": 682,
#             "hr": 4391,
#             "lks": 3,
#             "as": 0,
#             "dapd": 319,
#             "dapm": 264,
#             "ubers": 0,
#             "ubertypes": {},
#             "drops": 0,
#             "medkits": 60,
#             "medkits_hp": 1966,
#             "backstabs": 0,
#             "headshots": 1,
#             "headshots_hit": 1,
#             "sentries": 0,
#             "heal": 13,
#             "cpc": 2,
#             "ic": 0
#         },
#         "[U:1:1084634950]": {
#             "team": "Red",
#             "class_stats": [
#                 {
#                     "type": "medic",
#                     "kills": 2,
#                     "assists": 8,
#                     "deaths": 13,
#                     "dmg": 285,
#                     "weapon": {
#                         "crusaders_crossbow": {
#                             "kills": 1,
#                             "dmg": 285,
#                             "avg_dmg": 57,
#                             "shots": 175,
#                             "hits": 107
#                         },
#                         "world": {
#                             "kills": 1,
#                             "dmg": 0,
#                             "avg_dmg": 0,
#                             "shots": 0,
#                             "hits": 0
#                         }
#                     },
#                     "total_time": 1738
#                 }
#             ],
#             "kills": 2,
#             "deaths": 13,
#             "assists": 8,
#             "suicides": 0,
#             "kapd": "0.8",
#             "kpd": "0.2",
#             "dmg": 285,
#             "dmg_real": 32,
#             "dt": 4728,
#             "dt_real": 598,
#             "hr": 0,
#             "lks": 1,
#             "as": 0,
#             "dapd": 21,
#             "dapm": 9,
#             "ubers": 9,
#             "ubertypes": {
#                 "medigun": 9
#             },
#             "drops": 1,
#             "medkits": 14,
#             "medkits_hp": 396,
#             "backstabs": 0,
#             "headshots": 0,
#             "headshots_hit": 0,
#             "sentries": 0,
#             "heal": 29009,
#             "cpc": 8,
#             "ic": 0,
#             "medicstats": {
#                 "advantages_lost": 1,
#                 "biggest_advantage_lost": 17,
#                 "deaths_with_95_99_uber": 1,
#                 "deaths_within_20s_after_uber": 4,
#                 "avg_time_before_healing": 3.744444444444445,
#                 "avg_time_to_build": 68.18181818181819,
#                 "avg_time_before_using": 29.88888888888889,
#                 "avg_uber_length": 6.611111111111111
#             }
#         },
#         "[U:1:196913090]": {
#             "team": "Red",
#             "class_stats": [
#                 {
#                     "type": "demoman",
#                     "kills": 24,
#                     "assists": 10,
#                     "deaths": 12,
#                     "dmg": 12302,
#                     "weapon": {
#                         "tf_projectile_pipe_remote": {
#                             "kills": 13,
#                             "dmg": 6625,
#                             "avg_dmg": 47.66187050359712,
#                             "shots": 434,
#                             "hits": 116
#                         },
#                         "loch_n_load": {
#                             "kills": 11,
#                             "dmg": 5612,
#                             "avg_dmg": 93.53333333333333,
#                             "shots": 260,
#                             "hits": 50
#                         },
#                         "demokatana": {
#                             "kills": 0,
#                             "dmg": 65,
#                             "avg_dmg": 65,
#                             "shots": 0,
#                             "hits": 0
#                         }
#                     },
#                     "total_time": 1738
#                 }
#             ],
#             "kills": 24,
#             "deaths": 12,
#             "assists": 10,
#             "suicides": 0,
#             "kapd": "2.8",
#             "kpd": "2.0",
#             "dmg": 12302,
#             "dmg_real": 802,
#             "dt": 7621,
#             "dt_real": 415,
#             "hr": 9045,
#             "lks": 8,
#             "as": 0,
#             "dapd": 1025,
#             "dapm": 424,
#             "ubers": 0,
#             "ubertypes": {},
#             "drops": 0,
#             "medkits": 54,
#             "medkits_hp": 1852,
#             "backstabs": 0,
#             "headshots": 0,
#             "headshots_hit": 0,
#             "sentries": 0,
#             "heal": 0,
#             "cpc": 4,
#             "ic": 0
#         },
#         "[U:1:52343030]": {
#             "team": "Blue",
#             "class_stats": [
#                 {
#                     "type": "soldier",
#                     "kills": 12,
#                     "assists": 7,
#                     "deaths": 26,
#                     "dmg": 7604,
#                     "weapon": {
#                         "tf_projectile_rocket": {
#                             "kills": 9,
#                             "dmg": 5611,
#                             "avg_dmg": 55.554455445544555,
#                             "shots": 241,
#                             "hits": 91
#                         },
#                         "quake_rl": {
#                             "kills": 3,
#                             "dmg": 1993,
#                             "avg_dmg": 58.61764705882353,
#                             "shots": 61,
#                             "hits": 30
#                         }
#                     },
#                     "total_time": 1717
#                 }
#             ],
#             "kills": 12,
#             "deaths": 26,
#             "assists": 7,
#             "suicides": 0,
#             "kapd": "0.7",
#             "kpd": "0.5",
#             "dmg": 7604,
#             "dmg_real": 499,
#             "dt": 8094,
#             "dt_real": 837,
#             "hr": 4457,
#             "lks": 2,
#             "as": 4,
#             "dapd": 292,
#             "dapm": 262,
#             "ubers": 0,
#             "ubertypes": {},
#             "drops": 0,
#             "medkits": 73,
#             "medkits_hp": 2475,
#             "backstabs": 0,
#             "headshots": 0,
#             "headshots_hit": 0,
#             "sentries": 0,
#             "heal": 0,
#             "cpc": 3,
#             "ic": 0
#         },
#         "[U:1:47898421]": {
#             "team": "Blue",
#             "class_stats": [
#                 {
#                     "type": "demoman",
#                     "kills": 20,
#                     "assists": 4,
#                     "deaths": 17,
#                     "dmg": 9751,
#                     "weapon": {
#                         "tf_projectile_pipe_remote": {
#                             "kills": 11,
#                             "dmg": 6181,
#                             "avg_dmg": 46.82575757575758,
#                             "shots": 412,
#                             "hits": 108
#                         },
#                         "iron_bomber": {
#                             "kills": 8,
#                             "dmg": 3505,
#                             "avg_dmg": 64.9074074074074,
#                             "shots": 172,
#                             "hits": 51
#                         },
#                         "bottle": {
#                             "kills": 1,
#                             "dmg": 65,
#                             "avg_dmg": 65,
#                             "shots": 0,
#                             "hits": 0
#                         }
#                     },
#                     "total_time": 1738
#                 }
#             ],
#             "kills": 20,
#             "deaths": 17,
#             "assists": 4,
#             "suicides": 0,
#             "kapd": "1.4",
#             "kpd": "1.2",
#             "dmg": 9751,
#             "dmg_real": 842,
#             "dt": 7979,
#             "dt_real": 720,
#             "hr": 7713,
#             "lks": 5,
#             "as": 2,
#             "dapd": 573,
#             "dapm": 336,
#             "ubers": 0,
#             "ubertypes": {},
#             "drops": 0,
#             "medkits": 43,
#             "medkits_hp": 1585,
#             "backstabs": 0,
#             "headshots": 0,
#             "headshots_hit": 0,
#             "sentries": 0,
#             "heal": 0,
#             "cpc": 7,
#             "ic": 0
#         },
#         "[U:1:350814837]": {
#             "team": "Red",
#             "class_stats": [
#                 {
#                     "type": "scout",
#                     "kills": 25,
#                     "assists": 13,
#                     "deaths": 16,
#                     "dmg": 8701,
#                     "weapon": {
#                         "scattergun": {
#                             "kills": 22,
#                             "dmg": 8513,
#                             "avg_dmg": 26.686520376175547,
#                             "shots": 413,
#                             "hits": 291
#                         },
#                         "maxgun": {
#                             "kills": 2,
#                             "dmg": 188,
#                             "avg_dmg": 14.461538461538462,
#                             "shots": 63,
#                             "hits": 13
#                         },
#                         "world": {
#                             "kills": 1,
#                             "dmg": 0,
#                             "avg_dmg": 0,
#                             "shots": 0,
#                             "hits": 0
#                         }
#                     },
#                     "total_time": 1675
#                 },
#                 {
#                     "type": "sniper",
#                     "kills": 1,
#                     "assists": 0,
#                     "deaths": 1,
#                     "dmg": 300,
#                     "weapon": {
#                         "sniperrifle": {
#                             "kills": 1,
#                             "dmg": 300,
#                             "avg_dmg": 150,
#                             "shots": 3,
#                             "hits": 2
#                         }
#                     },
#                     "total_time": 61
#                 }
#             ],
#             "kills": 26,
#             "deaths": 17,
#             "assists": 13,
#             "suicides": 0,
#             "kapd": "2.3",
#             "kpd": "1.5",
#             "dmg": 9001,
#             "dmg_real": 623,
#             "dt": 7373,
#             "dt_real": 614,
#             "hr": 6593,
#             "lks": 5,
#             "as": 0,
#             "dapd": 529,
#             "dapm": 310,
#             "ubers": 0,
#             "ubertypes": {},
#             "drops": 0,
#             "medkits": 21,
#             "medkits_hp": 433,
#             "backstabs": 0,
#             "headshots": 1,
#             "headshots_hit": 2,
#             "sentries": 0,
#             "heal": 0,
#             "cpc": 12,
#             "ic": 0
#         },
#         "[U:1:377622168]": {
#             "team": "Red",
#             "class_stats": [
#                 {
#                     "type": "scout",
#                     "kills": 12,
#                     "assists": 13,
#                     "deaths": 20,
#                     "dmg": 4267,
#                     "weapon": {
#                         "scattergun": {
#                             "kills": 11,
#                             "dmg": 4181,
#                             "avg_dmg": 19.004545454545454,
#                             "shots": 352,
#                             "hits": 210
#                         },
#                         "pistol_scout": {
#                             "kills": 0,
#                             "dmg": 86,
#                             "avg_dmg": 17.2,
#                             "shots": 36,
#                             "hits": 5
#                         },
#                         "world": {
#                             "kills": 1,
#                             "dmg": 0,
#                             "avg_dmg": 0,
#                             "shots": 0,
#                             "hits": 0
#                         }
#                     },
#                     "total_time": 1545
#                 },
#                 {
#                     "type": "engineer",
#                     "kills": 0,
#                     "assists": 0,
#                     "deaths": 0,
#                     "dmg": 109,
#                     "weapon": {
#                         "frontier_justice": {
#                             "kills": 0,
#                             "dmg": 29,
#                             "avg_dmg": 7.25,
#                             "shots": 0,
#                             "hits": 0
#                         },
#                         "pistol": {
#                             "kills": 0,
#                             "dmg": 8,
#                             "avg_dmg": 8,
#                             "shots": 4,
#                             "hits": 1
#                         },
#                         "obj_sentrygun3": {
#                             "kills": 0,
#                             "dmg": 72,
#                             "avg_dmg": 2.5714285714285716,
#                             "shots": 0,
#                             "hits": 0
#                         }
#                     },
#                     "total_time": 170
#                 }
#             ],
#             "kills": 12,
#             "deaths": 20,
#             "assists": 13,
#             "suicides": 0,
#             "kapd": "1.3",
#             "kpd": "0.6",
#             "dmg": 4532,
#             "dmg_real": 258,
#             "dt": 6261,
#             "dt_real": 730,
#             "hr": 4092,
#             "lks": 3,
#             "as": 0,
#             "dapd": 226,
#             "dapm": 156,
#             "ubers": 0,
#             "ubertypes": {},
#             "drops": 0,
#             "medkits": 18,
#             "medkits_hp": 475,
#             "backstabs": 0,
#             "headshots": 0,
#             "headshots_hit": 0,
#             "sentries": 0,
#             "heal": 0,
#             "cpc": 8,
#             "ic": 0
#         },
#         "[U:1:168998121]": {
#             "team": "Blue",
#             "class_stats": [
#                 {
#                     "type": "soldier",
#                     "kills": 10,
#                     "assists": 6,
#                     "deaths": 22,
#                     "dmg": 5716,
#                     "weapon": {
#                         "quake_rl": {
#                             "kills": 8,
#                             "dmg": 4401,
#                             "avg_dmg": 50.01136363636363,
#                             "shots": 175,
#                             "hits": 72
#                         },
#                         "world": {
#                             "kills": 1,
#                             "dmg": 0,
#                             "avg_dmg": 0,
#                             "shots": 0,
#                             "hits": 0
#                         },
#                         "panic_attack": {
#                             "kills": 0,
#                             "dmg": 75,
#                             "avg_dmg": 9.375,
#                             "shots": 8,
#                             "hits": 6
#                         },
#                         "liberty_launcher": {
#                             "kills": 0,
#                             "dmg": 620,
#                             "avg_dmg": 34.44444444444444,
#                             "shots": 48,
#                             "hits": 13
#                         },
#                         "tf_projectile_rocket": {
#                             "kills": 1,
#                             "dmg": 620,
#                             "avg_dmg": 56.36363636363637,
#                             "shots": 28,
#                             "hits": 11
#                         }
#                     },
#                     "total_time": 1654
#                 },
#                 {
#                     "type": "pyro",
#                     "kills": 1,
#                     "assists": 0,
#                     "deaths": 1,
#                     "dmg": 18,
#                     "weapon": {
#                         "ai_flamethrower": {
#                             "kills": 1,
#                             "dmg": 18,
#                             "avg_dmg": 4.5,
#                             "shots": 0,
#                             "hits": 0
#                         }
#                     },
#                     "total_time": 84
#                 }
#             ],
#             "kills": 11,
#             "deaths": 23,
#             "assists": 6,
#             "suicides": 0,
#             "kapd": "0.7",
#             "kpd": "0.5",
#             "dmg": 5734,
#             "dmg_real": 353,
#             "dt": 8225,
#             "dt_real": 630,
#             "hr": 6132,
#             "lks": 3,
#             "as": 0,
#             "dapd": 249,
#             "dapm": 197,
#             "ubers": 0,
#             "ubertypes": {},
#             "drops": 0,
#             "medkits": 20,
#             "medkits_hp": 796,
#             "backstabs": 0,
#             "headshots": 0,
#             "headshots_hit": 0,
#             "sentries": 0,
#             "heal": 0,
#             "cpc": 8,
#             "ic": 0
#         },
#         "[U:1:1247683478]": {
#             "team": "Blue",
#             "class_stats": [
#                 {
#                     "type": "scout",
#                     "kills": 37,
#                     "assists": 7,
#                     "deaths": 19,
#                     "dmg": 9653,
#                     "weapon": {
#                         "scattergun": {
#                             "kills": 35,
#                             "dmg": 9573,
#                             "avg_dmg": 26.81512605042017,
#                             "shots": 426,
#                             "hits": 319
#                         },
#                         "maxgun": {
#                             "kills": 2,
#                             "dmg": 80,
#                             "avg_dmg": 16,
#                             "shots": 26,
#                             "hits": 5
#                         }
#                     },
#                     "total_time": 1736
#                 }
#             ],
#             "kills": 37,
#             "deaths": 19,
#             "assists": 7,
#             "suicides": 0,
#             "kapd": "2.3",
#             "kpd": "1.9",
#             "dmg": 9653,
#             "dmg_real": 1254,
#             "dt": 7746,
#             "dt_real": 710,
#             "hr": 6274,
#             "lks": 11,
#             "as": 0,
#             "dapd": 508,
#             "dapm": 333,
#             "ubers": 0,
#             "ubertypes": {},
#             "drops": 0,
#             "medkits": 23,
#             "medkits_hp": 560,
#             "backstabs": 0,
#             "headshots": 0,
#             "headshots_hit": 0,
#             "sentries": 0,
#             "heal": 0,
#             "cpc": 14,
#             "ic": 0
#         },
#         "[U:1:115028664]": {
#             "team": "Red",
#             "class_stats": [
#                 {
#                     "type": "soldier",
#                     "kills": 33,
#                     "assists": 5,
#                     "deaths": 28,
#                     "dmg": 10801,
#                     "weapon": {
#                         "quake_rl": {
#                             "kills": 32,
#                             "dmg": 10801,
#                             "avg_dmg": 57.452127659574465,
#                             "shots": 274,
#                             "hits": 163
#                         },
#                         "world": {
#                             "kills": 1,
#                             "dmg": 0,
#                             "avg_dmg": 0,
#                             "shots": 0,
#                             "hits": 0
#                         }
#                     },
#                     "total_time": 1738
#                 }
#             ],
#             "kills": 33,
#             "deaths": 28,
#             "assists": 5,
#             "suicides": 0,
#             "kapd": "1.4",
#             "kpd": "1.2",
#             "dmg": 10801,
#             "dmg_real": 1363,
#             "dt": 8912,
#             "dt_real": 887,
#             "hr": 4901,
#             "lks": 4,
#             "as": 1,
#             "dapd": 385,
#             "dapm": 372,
#             "ubers": 0,
#             "ubertypes": {},
#             "drops": 0,
#             "medkits": 85,
#             "medkits_hp": 3118,
#             "backstabs": 0,
#             "headshots": 0,
#             "headshots_hit": 0,
#             "sentries": 0,
#             "heal": 0,
#             "cpc": 0,
#             "ic": 0
#         },
#         "[U:1:215669943]": {
#             "team": "Blue",
#             "class_stats": [
#                 {
#                     "type": "medic",
#                     "kills": 2,
#                     "assists": 19,
#                     "deaths": 10,
#                     "dmg": 1348,
#                     "weapon": {
#                         "crusaders_crossbow": {
#                             "kills": 1,
#                             "dmg": 1153,
#                             "avg_dmg": 57.65,
#                             "shots": 199,
#                             "hits": 108
#                         },
#                         "ubersaw": {
#                             "kills": 1,
#                             "dmg": 195,
#                             "avg_dmg": 48.75,
#                             "shots": 0,
#                             "hits": 0
#                         }
#                     },
#                     "total_time": 1738
#                 }
#             ],
#             "kills": 2,
#             "deaths": 10,
#             "assists": 19,
#             "suicides": 0,
#             "kapd": "2.1",
#             "kpd": "0.2",
#             "dmg": 1348,
#             "dmg_real": 45,
#             "dt": 5125,
#             "dt_real": 460,
#             "hr": 0,
#             "lks": 1,
#             "as": 0,
#             "dapd": 134,
#             "dapm": 46,
#             "ubers": 13,
#             "ubertypes": {
#                 "medigun": 13
#             },
#             "drops": 0,
#             "medkits": 31,
#             "medkits_hp": 860,
#             "backstabs": 0,
#             "headshots": 0,
#             "headshots_hit": 0,
#             "sentries": 0,
#             "heal": 28933,
#             "cpc": 5,
#             "ic": 0,
#             "medicstats": {
#                 "deaths_with_95_99_uber": 0,
#                 "advantages_lost": 0,
#                 "biggest_advantage_lost": 0,
#                 "avg_time_before_healing": 3.9571428571428577,
#                 "avg_time_to_build": 63.84615384615385,
#                 "avg_time_before_using": 19.846153846153847,
#                 "avg_uber_length": 6.472727272727273
#             }
#         },
#         "[U:1:366656742]": {
#             "team": "Blue",
#             "class_stats": [
#                 {
#                     "type": "scout",
#                     "kills": 31,
#                     "assists": 13,
#                     "deaths": 20,
#                     "dmg": 7989,
#                     "weapon": {
#                         "scattergun": {
#                             "kills": 28,
#                             "dmg": 7680,
#                             "avg_dmg": 27.72563176895307,
#                             "shots": 373,
#                             "hits": 263
#                         },
#                         "world": {
#                             "kills": 2,
#                             "dmg": 0,
#                             "avg_dmg": 0,
#                             "shots": 0,
#                             "hits": 0
#                         },
#                         "the_winger": {
#                             "kills": 1,
#                             "dmg": 199,
#                             "avg_dmg": 11.705882352941176,
#                             "shots": 0,
#                             "hits": 0
#                         },
#                         "wrap_assassin": {
#                             "kills": 0,
#                             "dmg": 110,
#                             "avg_dmg": 5.5,
#                             "shots": 0,
#                             "hits": 0
#                         }
#                     },
#                     "total_time": 1683
#                 },
#                 {
#                     "type": "sniper",
#                     "kills": 1,
#                     "assists": 0,
#                     "deaths": 0,
#                     "dmg": 260,
#                     "weapon": {
#                         "sniperrifle": {
#                             "kills": 1,
#                             "dmg": 260,
#                             "avg_dmg": 130,
#                             "shots": 4,
#                             "hits": 2
#                         }
#                     },
#                     "total_time": 55
#                 }
#             ],
#             "kills": 32,
#             "deaths": 20,
#             "assists": 13,
#             "suicides": 0,
#             "kapd": "2.3",
#             "kpd": "1.6",
#             "dmg": 8249,
#             "dmg_real": 933,
#             "dt": 7412,
#             "dt_real": 701,
#             "hr": 4357,
#             "lks": 5,
#             "as": 0,
#             "dapd": 412,
#             "dapm": 284,
#             "ubers": 0,
#             "ubertypes": {},
#             "drops": 0,
#             "medkits": 37,
#             "medkits_hp": 1009,
#             "backstabs": 0,
#             "headshots": 1,
#             "headshots_hit": 1,
#             "sentries": 0,
#             "heal": 0,
#             "cpc": 10,
#             "ic": 0
#         }
#     },
#     "names": {
#         "[U:1:180084244]": "D'bestOman",
#         "[U:1:1084634950]": "Batman.",
#         "[U:1:196913090]": "K1lled",
#         "[U:1:52343030]": "Dream",
#         "[U:1:47898421]": "jR.",
#         "[U:1:350814837]": "Young Santana",
#         "[U:1:377622168]": "hypermegachungusultraupsizedelu",
#         "[U:1:168998121]": "Dashinix",
#         "[U:1:1247683478]": "chains",
#         "[U:1:115028664]": "trevsi skot",
#         "[U:1:215669943]": "Mr. Rotund",
#         "[U:1:366656742]": "BON"
#     },
#     "rounds": [
#         {
#             "start_time": 1729260782,
#             "winner": "Red",
#             "team": {
#                 "Blue": {
#                     "score": 0,
#                     "kills": 12,
#                     "dmg": 4474,
#                     "ubers": 1
#                 },
#                 "Red": {
#                     "score": 1,
#                     "kills": 18,
#                     "dmg": 6093,
#                     "ubers": 2
#                 }
#             },
#             "events": [
#                 {
#                     "type": "medic_death",
#                     "time": 42,
#                     "team": "Blue",
#                     "steamid": "[U:1:215669943]",
#                     "killer": "[U:1:180084244]"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 47,
#                     "team": "Red",
#                     "point": 3
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 66,
#                     "team": "Red",
#                     "point": 2
#                 },
#                 {
#                     "type": "charge",
#                     "medigun": "medigun",
#                     "time": 74,
#                     "steamid": "[U:1:1084634950]",
#                     "team": "Red"
#                 },
#                 {
#                     "type": "medic_death",
#                     "time": 82,
#                     "team": "Red",
#                     "steamid": "[U:1:1084634950]",
#                     "killer": "[U:1:47898421]"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 113,
#                     "team": "Blue",
#                     "point": 2
#                 },
#                 {
#                     "type": "charge",
#                     "medigun": "medigun",
#                     "time": 121,
#                     "steamid": "[U:1:215669943]",
#                     "team": "Blue"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 167,
#                     "team": "Red",
#                     "point": 2
#                 },
#                 {
#                     "type": "medic_death",
#                     "time": 173,
#                     "team": "Blue",
#                     "steamid": "[U:1:215669943]",
#                     "killer": "[U:1:115028664]"
#                 },
#                 {
#                     "type": "charge",
#                     "medigun": "medigun",
#                     "time": 179,
#                     "steamid": "[U:1:1084634950]",
#                     "team": "Red"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 190,
#                     "team": "Red",
#                     "point": 1
#                 },
#                 {
#                     "type": "round_win",
#                     "time": 190,
#                     "team": "Red"
#                 }
#             ],
#             "players": {
#                 "[U:1:47898421]": {
#                     "team": "Blue",
#                     "kills": 1,
#                     "dmg": 522
#                 },
#                 "[U:1:52343030]": {
#                     "team": "Blue",
#                     "kills": 1,
#                     "dmg": 815
#                 },
#                 "[U:1:377622168]": {
#                     "team": "Red",
#                     "kills": 3,
#                     "dmg": 820
#                 },
#                 "[U:1:366656742]": {
#                     "team": "Blue",
#                     "kills": 5,
#                     "dmg": 1378
#                 },
#                 "[U:1:1247683478]": {
#                     "team": "Blue",
#                     "kills": 4,
#                     "dmg": 1329
#                 },
#                 "[U:1:115028664]": {
#                     "team": "Red",
#                     "kills": 8,
#                     "dmg": 2035
#                 },
#                 "[U:1:196913090]": {
#                     "team": "Red",
#                     "kills": 5,
#                     "dmg": 1514
#                 },
#                 "[U:1:180084244]": {
#                     "team": "Red",
#                     "kills": 1,
#                     "dmg": 833
#                 },
#                 "[U:1:350814837]": {
#                     "team": "Red",
#                     "kills": 1,
#                     "dmg": 891
#                 },
#                 "[U:1:168998121]": {
#                     "team": "Blue",
#                     "kills": 1,
#                     "dmg": 382
#                 },
#                 "[U:1:215669943]": {
#                     "team": "Blue",
#                     "kills": 0,
#                     "dmg": 48
#                 },
#                 "[U:1:1084634950]": {
#                     "team": "Red",
#                     "kills": 0,
#                     "dmg": 0
#                 },
#                 "[U:1:909979503]": {
#                     "team": null,
#                     "kills": 0,
#                     "dmg": 0
#                 }
#             },
#             "firstcap": "Red",
#             "length": 190
#         },
#         {
#             "start_time": 1729260982,
#             "winner": "Blue",
#             "team": {
#                 "Blue": {
#                     "score": 1,
#                     "kills": 21,
#                     "dmg": 7858,
#                     "ubers": 3
#                 },
#                 "Red": {
#                     "score": 1,
#                     "kills": 17,
#                     "dmg": 8450,
#                     "ubers": 2
#                 }
#             },
#             "events": [
#                 {
#                     "type": "pointcap",
#                     "time": 239,
#                     "team": "Blue",
#                     "point": 3
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 262,
#                     "team": "Blue",
#                     "point": 4
#                 },
#                 {
#                     "type": "charge",
#                     "medigun": "medigun",
#                     "time": 293,
#                     "steamid": "[U:1:215669943]",
#                     "team": "Blue"
#                 },
#                 {
#                     "type": "charge",
#                     "medigun": "medigun",
#                     "time": 309,
#                     "steamid": "[U:1:1084634950]",
#                     "team": "Red"
#                 },
#                 {
#                     "type": "medic_death",
#                     "time": 337,
#                     "team": "Blue",
#                     "steamid": "[U:1:215669943]",
#                     "killer": "[U:1:180084244]"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 349,
#                     "team": "Red",
#                     "point": 4
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 371,
#                     "team": "Red",
#                     "point": 3
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 387,
#                     "team": "Red",
#                     "point": 2
#                 },
#                 {
#                     "type": "charge",
#                     "medigun": "medigun",
#                     "time": 399,
#                     "steamid": "[U:1:1084634950]",
#                     "team": "Red"
#                 },
#                 {
#                     "type": "medic_death",
#                     "time": 408,
#                     "team": "Red",
#                     "steamid": "[U:1:1084634950]",
#                     "killer": "[U:1:1247683478]"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 432,
#                     "team": "Blue",
#                     "point": 2
#                 },
#                 {
#                     "type": "medic_death",
#                     "time": 442,
#                     "team": "Red",
#                     "steamid": "[U:1:1084634950]",
#                     "killer": "[U:1:52343030]"
#                 },
#                 {
#                     "type": "charge",
#                     "medigun": "medigun",
#                     "time": 445,
#                     "steamid": "[U:1:215669943]",
#                     "team": "Blue"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 459,
#                     "team": "Blue",
#                     "point": 3
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 468,
#                     "team": "Blue",
#                     "point": 4
#                 },
#                 {
#                     "type": "charge",
#                     "medigun": "medigun",
#                     "time": 505,
#                     "steamid": "[U:1:215669943]",
#                     "team": "Blue"
#                 },
#                 {
#                     "type": "medic_death",
#                     "time": 510,
#                     "team": "Red",
#                     "steamid": "[U:1:1084634950]",
#                     "killer": "[U:1:168998121]"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 517,
#                     "team": "Blue",
#                     "point": 5
#                 },
#                 {
#                     "type": "round_win",
#                     "time": 517,
#                     "team": "Blue"
#                 }
#             ],
#             "players": {
#                 "[U:1:47898421]": {
#                     "team": "Blue",
#                     "kills": 4,
#                     "dmg": 2030
#                 },
#                 "[U:1:52343030]": {
#                     "team": "Blue",
#                     "kills": 5,
#                     "dmg": 1535
#                 },
#                 "[U:1:366656742]": {
#                     "team": "Blue",
#                     "kills": 4,
#                     "dmg": 1051
#                 },
#                 "[U:1:180084244]": {
#                     "team": "Red",
#                     "kills": 4,
#                     "dmg": 1506
#                 },
#                 "[U:1:350814837]": {
#                     "team": "Red",
#                     "kills": 7,
#                     "dmg": 1913
#                 },
#                 "[U:1:1247683478]": {
#                     "team": "Blue",
#                     "kills": 6,
#                     "dmg": 1535
#                 },
#                 "[U:1:377622168]": {
#                     "team": "Red",
#                     "kills": 0,
#                     "dmg": 348
#                 },
#                 "[U:1:168998121]": {
#                     "team": "Blue",
#                     "kills": 2,
#                     "dmg": 1386
#                 },
#                 "[U:1:115028664]": {
#                     "team": "Red",
#                     "kills": 3,
#                     "dmg": 1655
#                 },
#                 "[U:1:196913090]": {
#                     "team": "Red",
#                     "kills": 3,
#                     "dmg": 3028
#                 },
#                 "[U:1:215669943]": {
#                     "team": "Blue",
#                     "kills": 0,
#                     "dmg": 321
#                 },
#                 "[U:1:1084634950]": {
#                     "team": "Red",
#                     "kills": 0,
#                     "dmg": 0
#                 },
#                 "[U:1:909979503]": {
#                     "team": null,
#                     "kills": 0,
#                     "dmg": 0
#                 }
#             },
#             "firstcap": "Blue",
#             "length": 317
#         },
#         {
#             "start_time": 1729261309,
#             "winner": "Blue",
#             "team": {
#                 "Blue": {
#                     "score": 2,
#                     "kills": 15,
#                     "dmg": 5621,
#                     "ubers": 2
#                 },
#                 "Red": {
#                     "score": 1,
#                     "kills": 14,
#                     "dmg": 5430,
#                     "ubers": 0
#                 }
#             },
#             "events": [
#                 {
#                     "type": "pointcap",
#                     "time": 585,
#                     "team": "Blue",
#                     "point": 3
#                 },
#                 {
#                     "type": "medic_death",
#                     "time": 591,
#                     "team": "Red",
#                     "steamid": "[U:1:1084634950]",
#                     "killer": "[U:1:168998121]"
#                 },
#                 {
#                     "type": "charge",
#                     "medigun": "medigun",
#                     "time": 594,
#                     "steamid": "[U:1:215669943]",
#                     "team": "Blue"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 616,
#                     "team": "Blue",
#                     "point": 4
#                 },
#                 {
#                     "type": "charge",
#                     "medigun": "medigun",
#                     "time": 665,
#                     "steamid": "[U:1:215669943]",
#                     "team": "Blue"
#                 },
#                 {
#                     "type": "medic_death",
#                     "time": 686,
#                     "team": "Blue",
#                     "steamid": "[U:1:215669943]",
#                     "killer": "[U:1:350814837]"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 700,
#                     "team": "Red",
#                     "point": 4
#                 },
#                 {
#                     "type": "drop",
#                     "time": 725,
#                     "team": "Red",
#                     "steamid": "[U:1:1084634950]"
#                 },
#                 {
#                     "type": "medic_death",
#                     "time": 725,
#                     "team": "Red",
#                     "steamid": "[U:1:1084634950]",
#                     "killer": "[U:1:366656742]"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 734,
#                     "team": "Blue",
#                     "point": 4
#                 },
#                 {
#                     "type": "medic_death",
#                     "time": 739,
#                     "team": "Blue",
#                     "steamid": "[U:1:215669943]",
#                     "killer": "[U:1:115028664]"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 748,
#                     "team": "Blue",
#                     "point": 5
#                 },
#                 {
#                     "type": "round_win",
#                     "time": 748,
#                     "team": "Blue"
#                 }
#             ],
#             "players": {
#                 "[U:1:47898421]": {
#                     "team": "Blue",
#                     "kills": 3,
#                     "dmg": 1503
#                 },
#                 "[U:1:377622168]": {
#                     "team": "Red",
#                     "kills": 0,
#                     "dmg": 759
#                 },
#                 "[U:1:1247683478]": {
#                     "team": "Blue",
#                     "kills": 6,
#                     "dmg": 1905
#                 },
#                 "[U:1:115028664]": {
#                     "team": "Red",
#                     "kills": 4,
#                     "dmg": 1196
#                 },
#                 "[U:1:168998121]": {
#                     "team": "Blue",
#                     "kills": 3,
#                     "dmg": 695
#                 },
#                 "[U:1:350814837]": {
#                     "team": "Red",
#                     "kills": 4,
#                     "dmg": 1153
#                 },
#                 "[U:1:52343030]": {
#                     "team": "Blue",
#                     "kills": 1,
#                     "dmg": 819
#                 },
#                 "[U:1:196913090]": {
#                     "team": "Red",
#                     "kills": 5,
#                     "dmg": 1899
#                 },
#                 "[U:1:366656742]": {
#                     "team": "Blue",
#                     "kills": 2,
#                     "dmg": 596
#                 },
#                 "[U:1:180084244]": {
#                     "team": "Red",
#                     "kills": 1,
#                     "dmg": 423
#                 },
#                 "[U:1:215669943]": {
#                     "team": "Blue",
#                     "kills": 0,
#                     "dmg": 103
#                 },
#                 "[U:1:1084634950]": {
#                     "team": "Red",
#                     "kills": 0,
#                     "dmg": 0
#                 },
#                 "[U:1:909979503]": {
#                     "team": null,
#                     "kills": 0,
#                     "dmg": 0
#                 }
#             },
#             "firstcap": "Blue",
#             "length": 221
#         },
#         {
#             "start_time": 1729261540,
#             "winner": "Blue",
#             "team": {
#                 "Blue": {
#                     "score": 3,
#                     "kills": 20,
#                     "dmg": 6861,
#                     "ubers": 2
#                 },
#                 "Red": {
#                     "score": 1,
#                     "kills": 15,
#                     "dmg": 6889,
#                     "ubers": 1
#                 }
#             },
#             "events": [
#                 {
#                     "type": "medic_death",
#                     "time": 793,
#                     "team": "Red",
#                     "steamid": "[U:1:1084634950]",
#                     "killer": "[U:1:47898421]"
#                 },
#                 {
#                     "type": "medic_death",
#                     "time": 824,
#                     "team": "Blue",
#                     "steamid": "[U:1:215669943]",
#                     "killer": "[U:1:180084244]"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 831,
#                     "team": "Blue",
#                     "point": 3
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 861,
#                     "team": "Red",
#                     "point": 3
#                 },
#                 {
#                     "type": "charge",
#                     "medigun": "medigun",
#                     "time": 871,
#                     "steamid": "[U:1:1084634950]",
#                     "team": "Red"
#                 },
#                 {
#                     "type": "pointcap",
#                     "time": 884,
#                     "team": "Red",
#                     "point": 2
#                 },
#                 {
# ...
#                     "medigun": "medigun",
#                     "time": 1795,
#                     "steamid": "[U:1:215669943]",
#                     "team": "Blue"
#                 },
#                 {
#                     "type": "round_win",
#                     "time": 1799,
#                     "team": null
#                 }
#             ],
#             "players": {
#                 "[U:1:350814837]": {
#                     "team": "Red",
#                     "kills": 3,
#                     "dmg": 1534
#                 },
#                 "[U:1:47898421]": {
#                     "team": "Blue",
#                     "kills": 1,
#                     "dmg": 970
#                 },
#                 "[U:1:366656742]": {
#                     "team": "Blue",
#                     "kills": 11,
#                     "dmg": 1820
#                 },
#                 "[U:1:377622168]": {
#                     "team": "Red",
#                     "kills": 5,
#                     "dmg": 732
#                 },
#                 "[U:1:52343030]": {
#                     "team": "Blue",
#                     "kills": 3,
#                     "dmg": 1993
#                 },
#                 "[U:1:1247683478]": {
#                     "team": "Blue",
#                     "kills": 8,
#                     "dmg": 1970
#                 },
#                 "[U:1:115028664]": {
#                     "team": "Red",
#                     "kills": 5,
#                     "dmg": 1519
#                 },
#                 "[U:1:180084244]": {
#                     "team": "Red",
#                     "kills": 5,
#                     "dmg": 1786
#                 },
#                 "[U:1:196913090]": {
#                     "team": "Red",
#                     "kills": 2,
#                     "dmg": 1229
#                 },
#                 "[U:1:1084634950]": {
#                     "team": "Red",
#                     "kills": 1,
#                     "dmg": 66
#                 },
#                 "[U:1:168998121]": {
#                     "team": "Blue",
#                     "kills": 0,
#                     "dmg": 368
#                 },
#                 "[U:1:215669943]": {
#                     "team": "Blue",
#                     "kills": 1,
#                     "dmg": 146
#                 },
#                 "[U:1:909979503]": {
#                     "team": null,
#                     "kills": 0,
#                     "dmg": 0
#                 },
#                 "[U:1:984515752]": {
#                     "team": null,
#                     "kills": 0,
#                     "dmg": 0
#                 },
#                 "[U:1:432477029]": {
#                     "team": null,
#                     "kills": 0,
#                     "dmg": 0
#                 }
#             },
#             "firstcap": "Red",
#             "length": 280
#         }
#     ],
#     "healspread": {
#         "[U:1:1084634950]": {
#             "[U:1:196913090]": 9045,
#             "[U:1:377622168]": 4092,
#             "[U:1:115028664]": 4901,
#             "[U:1:350814837]": 6580,
#             "[U:1:180084244]": 4391
#         },
#         "[U:1:215669943]": {
#             "[U:1:47898421]": 7713,
#             "[U:1:52343030]": 4457,
#             "[U:1:366656742]": 4357,
#             "[U:1:1247683478]": 6274,
#             "[U:1:168998121]": 6132
#         }
#     },
#     "classkills": {
#         "[U:1:196913090]": {
#             "soldier": 9,
#             "demoman": 4,
#             "scout": 10,
#             "medic": 1
#         },
#         "[U:1:115028664]": {
#             "scout": 12,
#             "soldier": 14,
#             "demoman": 4,
#             "medic": 3
#         },
#         "[U:1:180084244]": {
#             "medic": 3,
#             "demoman": 5,
#             "scout": 4,
#             "soldier": 6
#         },
#         "[U:1:168998121]": {
#             "soldier": 5,
#             "scout": 2,
#             "medic": 3,
#             "demoman": 1
#         },
#         "[U:1:350814837]": {
#             "scout": 9,
#             "soldier": 14,
#             "demoman": 1,
#             "medic": 2
#         },
#         "[U:1:1247683478]": {
#             "soldier": 13,
#             "scout": 12,
#             "medic": 4,
#             "demoman": 7,
#             "sniper": 1
#         },
#         "[U:1:366656742]": {
#             "scout": 9,
#             "soldier": 18,
#             "medic": 2,
#             "demoman": 2,
#             "sniper": 1
#         },
#         "[U:1:377622168]": {
#             "scout": 4,
#             "demoman": 2,
#             "soldier": 5,
#             "pyro": 1
#         },
#         "[U:1:47898421]": {
#             "medic": 3,
#             "soldier": 8,
#             "scout": 7,
#             "demoman": 1,
#             "heavyweapons": 1
#         },
#         "[U:1:52343030]": {
#             "scout": 5,
#             "soldier": 6,
#             "medic": 1
#         },
#         "[U:1:215669943]": {
#             "scout": 1,
#             "demoman": 1
#         },
#         "[U:1:1084634950]": {
#             "demoman": 1,
#             "medic": 1
#         }
#     },
#     "classdeaths": {
#         "[U:1:52343030]": {
#             "demoman": 5,
#             "soldier": 11,
#             "scout": 10
#         },
#         "[U:1:1247683478]": {
#             "soldier": 7,
#             "scout": 6,
#             "demoman": 6
#         },
#         "[U:1:47898421]": {
#             "demoman": 4,
#             "soldier": 8,
#             "scout": 3,
#             "sniper": 1,
#             "medic": 1
#         },
#         "[U:1:215669943]": {
#             "soldier": 6,
#             "scout": 1,
#             "demoman": 1,
#             "medic": 1,
#             "sniper": 1
#         },
#         "[U:1:180084244]": {
#             "soldier": 6,
#             "scout": 12,
#             "demoman": 6
#         },
#         "[U:1:168998121]": {
#             "soldier": 9,
#             "scout": 10,
#             "demoman": 4
#         },
#         "[U:1:366656742]": {
#             "scout": 7,
#             "soldier": 9,
#             "demoman": 4
#         },
#         "[U:1:115028664]": {
#             "scout": 20,
#             "soldier": 5,
#             "demoman": 3
#         },
#         "[U:1:350814837]": {
#             "scout": 10,
#             "soldier": 3,
#             "demoman": 3,
#             "medic": 1
#         },
#         "[U:1:1084634950]": {
#             "demoman": 3,
#             "scout": 5,
#             "soldier": 3,
#             "sniper": 1,
#             "pyro": 1
#         },
#         "[U:1:377622168]": {
#             "soldier": 4,
#             "scout": 12,
#             "demoman": 4
#         },
#         "[U:1:196913090]": {
#             "scout": 9,
#             "demoman": 1,
#             "soldier": 1,
#             "medic": 1
#         }
#     },
#     "classkillassists": {
#         "[U:1:196913090]": {
#             "soldier": 12,
#             "demoman": 5,
#             "scout": 15,
#             "medic": 2
#         },
#         "[U:1:350814837]": {
#             "soldier": 21,
#             "scout": 10,
#             "demoman": 5,
#             "medic": 3
#         },
#         "[U:1:115028664]": {
#             "scout": 14,
#             "soldier": 17,
#             "demoman": 4,
#             "medic": 3
#         },
#         "[U:1:180084244]": {
#             "medic": 3,
#             "soldier": 9,
#             "demoman": 5,
#             "scout": 4
#         },
#         "[U:1:168998121]": {
#             "soldier": 7,
#             "scout": 5,
#             "medic": 4,
#             "demoman": 1
#         },
#         "[U:1:366656742]": {
#             "soldier": 23,
#             "scout": 14,
#             "medic": 4,
#             "demoman": 3,
#             "sniper": 1
#         },
#         "[U:1:377622168]": {
#             "soldier": 14,
#             "scout": 8,
#             "demoman": 2,
#             "pyro": 1
#         },
#         "[U:1:1247683478]": {
#             "soldier": 17,
#             "scout": 12,
#             "medic": 4,
#             "demoman": 9,
#             "sniper": 1,
#             "heavyweapons": 1
#         },
#         "[U:1:47898421]": {
#             "medic": 4,
#             "soldier": 11,
#             "scout": 7,
#             "demoman": 1,
#             "heavyweapons": 1
#         },
#         "[U:1:215669943]": {
#             "medic": 3,
#             "soldier": 11,
#             "scout": 4,
#             "demoman": 3
#         },
#         "[U:1:52343030]": {
#             "scout": 9,
#             "soldier": 8,
#             "medic": 1,
#             "sniper": 1
#         },
#         "[U:1:1084634950]": {
#             "soldier": 3,
#             "scout": 5,
#             "demoman": 1,
#             "medic": 1
#         }
#     },
#     "chat": [
#         {
#             "steamid": "[U:1:350814837]",
#             "name": "Young Santana",
#             "msg": "bro"
#         },
#         {
#             "steamid": "[U:1:350814837]",
#             "name": "Young Santana",
#             "msg": "like"
#         },
#         {
#             "steamid": "[U:1:47898421]",
#             "name": "jR.",
#             "msg": "tLOL"
#         },
#         {
#             "steamid": "[U:1:47898421]",
#             "name": "jR.",
#             "msg": "LOL"
#         },
#         {
#             "steamid": "[U:1:115028664]",
#             "name": "trevsi skot",
#             "msg": "OLOL"
#         },
#         {
#             "steamid": "[U:1:366656742]",
#             "name": "BON",
#             "msg": "bruyh"
#         },
#         {
#             "steamid": "[U:1:366656742]",
#             "name": "BON",
#             "msg": "brtuh"
#         },
#         {
#             "steamid": "[U:1:366656742]",
#             "name": "BON",
#             "msg": "bruh"
#         },
#         {
#             "steamid": "[U:1:350814837]",
#             "name": "Young Santana",
#             "msg": "WTF"
#         },
#         {
#             "steamid": "[U:1:366656742]",
#             "name": "BON",
#             "msg": "(=\u00b4\u11ba\uff40=)"
#         },
#         {
#             "steamid": "[U:1:350814837]",
#             "name": "Young Santana",
#             "msg": "0mg"
#         },
#         {
#             "steamid": "[U:1:350814837]",
#             "name": "Young Santana",
#             "msg": "what my team do"
#         },
#         {
#             "steamid": "[U:1:47898421]",
#             "name": "jR.",
#             "msg": "HAHAHA"
#         },
#         {
#             "steamid": "[U:1:115028664]",
#             "name": "trevsi skot",
#             "msg": "med down tho"
#         },
#         {
#             "steamid": "[U:1:366656742]",
#             "name": "BON",
#             "msg": "jR's had enough"
#         },
#         {
#             "steamid": "[U:1:180084244]",
#             "name": "D'bestOman",
#             "msg": "mr rotund"
#         },
#         {
#             "steamid": "[U:1:215669943]",
#             "name": "Mr. Rotund",
#             "msg": "dabestoman"
#         },
#         {
#             "steamid": "[U:1:366656742]",
#             "name": "BON",
#             "msg": "LMFAO"
#         },
#         {
#             "steamid": "[U:1:168998121]",
#             "name": "Dashinix",
#             "msg": "INSANE PLAY"
#         },
#         {
#             "steamid": "[U:1:52343030]",
#             "name": "Dream",
#             "msg": "u pick up for the purple rockets?"
#         },
#         {
#             "steamid": "[U:1:180084244]",
#             "name": "D'bestOman",
#             "msg": "tes"
#         },
#         {
#             "steamid": "[U:1:366656742]",
#             "name": "BON",
#             "msg": "LMFAOO"
#         },
#         {
#             "steamid": "[U:1:366656742]",
#             "name": "BON",
#             "msg": "LMFAOOO"
#         },
#         {
#             "steamid": "[U:1:168998121]",
#             "name": "Dashinix",
#             "msg": "oops"
#         },
#         {
#             "steamid": "[U:1:115028664]",
#             "name": "trevsi skot",
#             "msg": "stop rushing last mannnnn"
#         },
#         {
#             "steamid": "[U:1:168998121]",
#             "name": "Dashinix",
#             "msg": "no"
#         },
#         {
#             "steamid": "[U:1:1247683478]",
#             "name": "chains",
#             "msg": "WTF"
#         },
#         {
#             "steamid": "[U:1:168998121]",
#             "name": "Dashinix",
#             "msg": "fuck you scared me"
#         },
#         {
#             "steamid": "[U:1:168998121]",
#             "name": "Dashinix",
#             "msg": "med down"
#         },
#         {
#             "steamid": "[U:1:180084244]",
#             "name": "D'bestOman",
#             "msg": "bonathan"
#         },
#         {
#             "steamid": "[U:1:47898421]",
#             "name": "jR.",
#             "msg": "Prec_mark"
#         },
#         {
#             "steamid": "[U:1:432477029]",
#             "name": "Lucifear",
#             "msg": "wtf freedom blaster"
#         },
#         {
#             "steamid": "[U:1:47898421]",
#             "name": "jR.",
#             "msg": "U SCARE ME"
#         },
#         {
#             "steamid": "[U:1:180084244]",
#             "name": "D'bestOman",
#             "msg": "bon"
#         },
#         {
#             "steamid": "[U:1:180084244]",
#             "name": "D'bestOman",
#             "msg": "bon"
#         },
#         {
#             "steamid": "[U:1:168998121]",
#             "name": "Dashinix",
#             "msg": "ow\\"
#         },
#         {
#             "steamid": "[U:1:168998121]",
#             "name": "Dashinix",
#             "msg": "jumpcare"
#         },
#         {
#             "steamid": "[U:1:984515752]",
#             "name": "Typhlosion",
#             "msg": "dashnix why are u pyro"
#         },
#         {
#             "steamid": "[U:1:168998121]",
#             "name": "Dashinix",
#             "msg": "trying somethin"
#         },
#         {
#             "steamid": "[U:1:984515752]",
#             "name": "Typhlosion",
#             "msg": "its over"
#         },
#         {
#             "steamid": "[U:1:168998121]",
#             "name": "Dashinix",
#             "msg": "did not  work"
#         },
#         {
#             "steamid": "[U:1:52343030]",
#             "name": "Dream",
#             "msg": "xd"
#         },
#         {
#             "steamid": "[U:1:52343030]",
#             "name": "Dream",
#             "msg": "xd"
#         },
#         {
#             "steamid": "[U:1:1084634950]",
#             "name": "Batman.",
#             "msg": "gg"
#         },
#         {
#             "steamid": "[U:1:1084634950]",
#             "name": "Batman.",
#             "msg": ".ss"
#         }
#     ],
#     "info": {
#         "map": "cp_gullywash_f9",
#         "supplemental": true,
#         "total_length": 1738,
#         "hasRealDamage": true,
#         "hasWeaponDamage": true,
#         "hasAccuracy": true,
#         "hasHP": true,
#         "hasHP_real": true,
#         "hasHS": true,
#         "hasHS_hit": true,
#         "hasBS": false,
#         "hasCP": true,
#         "hasSB": false,
#         "hasDT": true,
#         "hasAS": true,
#         "hasHR": true,
#         "hasIntel": false,
#         "AD_scoring": false,
#         "notifications": [],
#         "title": "Matcha Bookable: RED vs BLU",
#         "date": 1729269799,
#         "uploader": {
#             "id": "76561198158013527",
#             "name": "avan_\u30b7",
#             "info": "LogsTF 2.6.2"
#         }
#     },
#     "killstreaks": [
#         {
#             "steamid": "[U:1:366656742]",
#             "streak": 3,
#             "time": 80
#         },
#         {
#             "steamid": "[U:1:115028664]",
#             "streak": 3,
#             "time": 34
#         },
#         {
#             "steamid": "[U:1:115028664]",
#             "streak": 3,
#             "time": 168
#         },
#         {
#             "steamid": "[U:1:350814837]",
#             "streak": 4,
#             "time": 309
#         },
#         {
#             "steamid": "[U:1:1247683478]",
#             "streak": 3,
#             "time": 408
#         },
#         {
#             "steamid": "[U:1:168998121]",
#             "streak": 3,
#             "time": 591
#         },
#         {
#             "steamid": "[U:1:1247683478]",
#             "streak": 3,
#             "time": 872
#         },
#         {
#             "steamid": "[U:1:350814837]",
#             "streak": 3,
#             "time": 1467
#         },
#         {
#             "steamid": "[U:1:366656742]",
#             "streak": 3,
#             "time": 1549
#         },
#         {
#             "steamid": "[U:1:196913090]",
#             "streak": 5,
#             "time": 1173
#         },
#         {
#             "steamid": "[U:1:377622168]",
#             "streak": 3,
#             "time": 1577
#         }
#     ],
#     "success": true
# }

# %% [markdown]
# ## Storing the data in a file

# %%
numQueries = 10
querySuccessCode = 200
log_data = []

# This will store numQueries amount of queries in the same file
with open('log_outputs.json', 'w') as f:
    for i in range(numQueries):
        # This assumes log_id is sequential, which is stated to be true.
        URLQuery = "http://logs.tf/api/v1/log/" + str(3736855 - i)
        response = requests.get(URLQuery)
        if(response.status_code != querySuccessCode):
            print("An error has occured with query: {URLQuery}")
            continue
        data = response.json()
        log_data.append(data)
    json.dump(log_data, f, indent=4)

# %% [markdown]
# # Cleaning with Pandas

# %%
import pandas as pd

df = pd.read_json("log_outputs.json")

# %%
print(df[:1])
df.drop(columns=['chat'], inplace=True)
# Out:
#    version                                              teams  length  \
# 0        3  {'Red': {'score': 3, 'kills': 115, 'deaths': 0...    1738
#
#                                              players  \
# 0  {'[U:1:180084244]': {'team': 'Red', 'class_sta...
#
#                                                names  \
# 0  {'[U:1:180084244]': 'D'bestOman', '[U:1:108463...
#
#                                               rounds  \
# 0  [{'start_time': 1729260782, 'winner': 'Red', '...
#
#                                           healspread  \
# 0  {'[U:1:1084634950]': {'[U:1:196913090]': 9045,...
#
#                                           classkills  \
# 0  {'[U:1:196913090]': {'soldier': 9, 'demoman': ...
#
#                                          classdeaths  \
# 0  {'[U:1:52343030]': {'demoman': 5, 'soldier': 1...
#
#                                     classkillassists  \
# 0  {'[U:1:196913090]': {'soldier': 12, 'demoman':...
#
#                                                 chat  \
# 0  [{'steamid': '[U:1:350814837]', 'name': 'Young...
#
#                                                 info  \
# 0  {'map': 'cp_gullywash_f9', 'supplemental': Tru...
#
#                                          killstreaks  success
# 0  [{'steamid': '[U:1:366656742]', 'streak': 3, '...     True

# %%
print(df[:1])
# Out:
#    version                                              teams  length  \
# 0        3  {'Red': {'score': 3, 'kills': 115, 'deaths': 0...    1738
#
#                                              players  \
# 0  {'[U:1:180084244]': {'team': 'Red', 'class_sta...
#
#                                                names  \
# 0  {'[U:1:180084244]': 'D'bestOman', '[U:1:108463...
#
#                                               rounds  \
# 0  [{'start_time': 1729260782, 'winner': 'Red', '...
#
#                                           healspread  \
# 0  {'[U:1:1084634950]': {'[U:1:196913090]': 9045,...
#
#                                           classkills  \
# 0  {'[U:1:196913090]': {'soldier': 9, 'demoman': ...
#
#                                          classdeaths  \
# 0  {'[U:1:52343030]': {'demoman': 5, 'soldier': 1...
#
#                                     classkillassists  \
# 0  {'[U:1:196913090]': {'soldier': 12, 'demoman':...
#
#                                                 info  \
# 0  {'map': 'cp_gullywash_f9', 'supplemental': Tru...
#
#                                          killstreaks  success
# 0  [{'steamid': '[U:1:366656742]', 'streak': 3, '...     True
